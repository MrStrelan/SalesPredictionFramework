# %%
pip install tradingeconomics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/56.6 kB ? eta -:--:--
#    ------- -------------------------------- 10.2/56.6 kB ? eta -:--:--
#    -------------- ------------------------- 20.5/56.6 kB 162.5 kB/s eta 0:00:01
#    ---------------------------- ----------- 41.0/56.6 kB 245.8 kB/s eta 0:00:01
#    ---------------------------------------- 56.6/56.6 kB 295.5 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tradingeconomics as te

te.login('df6fe91a9abc498:p6b8bb93snwca25')
# Out:
# 'Logged with df6fe91a9abc498'

# %%
mydata = te.getHistoricalData(country='mexico', indicator='gdp', initDate='2024-01-01', endDate='2024-12-31', output_type='df')
print(mydata)
# Out:
#                                              Country Category  \
# 0  Free accounts have access to the following cou...
#
#                             DateTime  Value Frequency HistoricalDataSymbol  \
# 0  2025-03-30T20:54:19.4340059+00:00    0.0      None                 None
#
#   LastUpdate
# 0       None

# %%
mydata = te.getHistoricalUpdates(output_type='df')
print(mydata)
# Out:
#             Country                    Category  HistoricalDataSymbol  \
# 0             Egypt           Consumer Spending           EGYPTCONSPE
# 1    United Kingdom          CPI Transportation       UNITEDKINCPITRA
# 2    United Kingdom       CPI Housing Utilities          UNITEDKINCHU
# 3    United Kingdom            Energy Inflation             GBRENEINF
# 4    United Kingdom              Rent Inflation             GBRRENINF
# ..              ...                         ...                   ...
# 995   United States         Banks Balance Sheet    UNITEDSTABANBALSHE
# 996   United States       Weekly Economic Index                USAWEI
# 997         Germany  Central Bank Balance Sheet   GERMANYCENBANBALSHE
# 998       Hong Kong               Housing Index        HONGKONGHOUIND
# 999       Australia  Central Bank Balance Sheet  AUSTRALIACENBANBALSH
#
#               LastUpdate
# 0    2025-03-26T08:42:00
# 1    2025-03-26T08:44:00
# 2    2025-03-26T08:44:00
# ...

# %%
te.getIndicatorData()
# Out:
# [{'Category': 'ZEW Economic Sentiment Index', 'CategoryGroup': 'Business'},
#  {'Category': 'ZEW Current Conditions', 'CategoryGroup': 'Business'},
#  {'Category': 'Youth Unemployment Rate', 'CategoryGroup': 'Labour'},
#  {'Category': 'WPI Manufacturing YoY', 'CategoryGroup': 'Prices'},
#  {'Category': 'WPI Fuel YoY', 'CategoryGroup': 'Prices'},
#  {'Category': 'WPI Food Index YoY', 'CategoryGroup': 'Prices'},
#  {'Category': 'Withholding Tax Rate', 'CategoryGroup': 'Taxes'},
#  {'Category': 'Wholesale Sales', 'CategoryGroup': 'Business'},
#  {'Category': 'Wholesale Prices YoY', 'CategoryGroup': 'Prices'},
#  {'Category': 'Wholesale Prices MoM', 'CategoryGroup': 'Prices'},
#  {'Category': 'Wholesale Prices', 'CategoryGroup': 'Prices'},
#  {'Category': 'Wholesale Inventories', 'CategoryGroup': 'Business'},
#  {'Category': 'Weighted Median CPI YoY', 'CategoryGroup': 'Prices'},
#  {'Category': 'Weighted Median CPI QoQ', 'CategoryGroup': 'Prices'},
# ...

# %%
te.getAllCountries()

# %%
mydata = te.getIndicatorData(country='all', indicators='gdp', output_type='df')
print(mydata)
# Out:
# Error: You can not use both country and indicators parameters at the same time.

# %%
import wbdata
import datetime

# Set country (ISO 2 or 3 code) and date range
countries = ["USA", "FRA", "DEU", "JPN"]  # use ISO-3 codes
data_date = (datetime.datetime(2015, 1, 1), datetime.datetime(2025, 1, 1))

# Example indicators
indicators = {
    'FR.INR.RINR': 'Interest Rate',  # Real interest rate
}

df = wbdata.get_dataframe(indicators, country=countries, date=("2023", "2024"))

# %%
import wbdata
wbdata.get_sources()
# Out:
# d:\School\ITU\Coding\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#   id  name
# ----  --------------------------------------------------------------------
#    1  Doing Business
#    2  World Development Indicators
#    3  Worldwide Governance Indicators
#    5  Subnational Malnutrition Database
#    6  International Debt Statistics
#   11  Africa Development Indicators
#   12  Education Statistics
#   13  Enterprise Surveys
#   14  Gender Statistics
#   15  Global Economic Monitor
#   16  Health Nutrition and Population Statistics
#   18  IDA Results Measurement System
#   19  Millennium Development Goals
#   20  Quarterly Public Sector Debt
#   22  Quarterly External Debt Statistics SDDS
#   23  Quarterly External Debt Statistics GDDS
#   25  Jobs
#   27  Global Economic Prospects
#   28  Global Financial Inclusion
# ...

# %%
wbdata.get_indicators(source=1)
# Out:
# id                                                 name
# -------------------------------------------------  ---------------------------------------------------------------------------------------------------------------
# ENF.CONT.COEN.ATDR                                 Enforcing contracts: Alternative dispute resolution (0-3) (DB16-20 methodology)
# ENF.CONT.COEN.ATFE.PR                              Enforcing contracts: Attorney fees (% of claim)
# ENF.CONT.COEN.COST.ZS                              Enforcing contracts: Cost (% of claim)
# ENF.CONT.COEN.COST.ZS.DFRN                         Enforcing contracts: Cost (% of claim) - Score
# ENF.CONT.COEN.CSMG                                 Enforcing contracts: Case management (0-6) (DB16-20 methodology)
# ENF.CONT.COEN.CTAU                                 Enforcing contracts: Court automation (0-4) (DB17-20 methodology)
# ENF.CONT.COEN.CTFE.PR                              Enforcing contracts: Court fees (% of claim)
# ...

# %%
import pandas as pd

# Load CSV
df = pd.read_csv("BCI.csv")  # Update with actual file path

# Rename for easier access
df.columns = ['Country', 'Date', 'Value']

# Convert 'Date' to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Sort
df = df.sort_values(['Country', 'Date'])

# Optional: Set datetime index (good for time series)
df.set_index('Date', inplace=True)

# Preview
print(df.head())
# Out:
# d:\School\ITU\Coding\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#               Country     Value
# Date
# 1969-01-01  Australia  100.8958
# 1969-02-01  Australia  101.0810
# 1969-03-01  Australia  101.1572
# 1969-04-01  Australia  101.1705
# 1969-05-01  Australia  101.1896

# %%
# Unique 
print(df['Country'].unique())
# Out:
# ['Australia' 'Austria' 'Belgium' 'Brazil' 'Bulgaria' 'Canada' 'Chile'
#  'China (People’s Republic of)' 'Colombia' 'Costa Rica' 'Croatia'
#  'Czechia' 'Denmark' 'Estonia' 'Euro area (19 countries)'
#  'European Union (27 countries from 01/02/2020)' 'Finland' 'France' 'G20'
#  'G7' 'Germany' 'Greece' 'Hungary' 'India' 'Indonesia' 'Ireland' 'Israel'
#  'Italy' 'Japan' 'Korea' 'Latvia' 'Lithuania' 'Luxembourg'
#  'Major five Asia economies' 'Mexico' 'Netherlands' 'New Zealand' 'Norway'
#  'OECD' 'OECD Europe' 'OECD excluding the euro area' 'Poland' 'Portugal'
#  'Romania' 'Russia' 'Slovak Republic' 'Slovenia' 'South Africa' 'Spain'
#  'Sweden' 'Switzerland' 'Türkiye' 'United Kingdom' 'United States']

# %%
print(df['Country']=='Denmark')
# Out:
# Date
# 1969-01-01    False
# 1969-02-01    False
# 1969-03-01    False
# 1969-04-01    False
# 1969-05-01    False
#               ...
# 2068-08-01    False
# 2068-09-01    False
# 2068-10-01    False
# 2068-11-01    False
# 2068-12-01    False
# Name: Country, Length: 25850, dtype: bool
